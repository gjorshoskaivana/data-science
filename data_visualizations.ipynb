# %% [markdown]
# The Dataset for this exercise depends on your index number i.e number_of_data_set = index % 10:
#
#
# 0.  https://www.kaggle.com/tunguz/us-elections-dataset
# 1.  https://www.kaggle.com/andrewmvd/heart-failure-clinical-data
# 2.  https://www.kaggle.com/sootersaalu/amazon-top-50-bestselling-books-2009-2019
# 3.  https://www.kaggle.com/anmolkumar/health-insurance-cross-sell-prediction
# 4.  https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009
# 5.  https://www.kaggle.com/anmolkumar/house-price-prediction-challenge
# 6.  https://www.kaggle.com/rishidamarlajudicial-expenditures-across-all-50-states
# 7.  https://www.kaggle.com/arslanali4343/real-estate-dataset
# 8.  https://www.kaggle.com/terenceshin/covid19s-impact-on-airport-traffic
# 9.  https://www.kaggle.com/arslanali4343/top-personality-dataset

# %% [markdown]
# # Import libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from datetime import date

import requests
from bs4 import BeautifulSoup
from IPython.display import HTML
# Setting up 'requests' to make HTTPS requests properly takes some extra steps... we'll skip them for now.
requests.packages.urllib3.disable_warnings()

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read dataset

# %% [markdown]
# Link to the dataset: https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009

# %%
dataset = pd.read_csv('/content/drive/My Drive/Datasets/winequality-red.csv')
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %% [markdown]
# **Show info and the first 5 rows of your Dataset**

# %%
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %% [markdown]
# # Statistics

# %%
dataset.mean()
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# quality                  5.636023
# dtype: float64

# %%
dataset.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
dataset.std()
# Out:
# fixed acidity            1.741096
# volatile acidity         0.179060
# citric acid              0.194801
# residual sugar           1.409928
# chlorides                0.047065
# free sulfur dioxide     10.460157
# total sulfur dioxide    32.895324
# density                  0.001887
# pH                       0.154386
# sulphates                0.169507
# alcohol                  1.065668
# quality                  0.807569
# dtype: float64

# %%
dataset.min()
# Out:
# fixed acidity           4.60000
# volatile acidity        0.12000
# citric acid             0.00000
# residual sugar          0.90000
# chlorides               0.01200
# free sulfur dioxide     1.00000
# total sulfur dioxide    6.00000
# density                 0.99007
# pH                      2.74000
# sulphates               0.33000
# alcohol                 8.40000
# quality                 3.00000
# dtype: float64

# %%
dataset.max()
# Out:
# fixed acidity            15.90000
# volatile acidity          1.58000
# citric acid               1.00000
# residual sugar           15.50000
# chlorides                 0.61100
# free sulfur dioxide      72.00000
# total sulfur dioxide    289.00000
# density                   1.00369
# pH                        4.01000
# sulphates                 2.00000
# alcohol                  14.90000
# quality                   8.00000
# dtype: float64

# %%
dataset.quantile([.1, .25, .5, .75], axis = 0)
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0.10            6.5              0.31         0.01  ...       0.50      9.3      5.0
# 0.25            7.1              0.39         0.09  ...       0.55      9.5      5.0
# 0.50            7.9              0.52         0.26  ...       0.62     10.2      6.0
# 0.75            9.2              0.64         0.42  ...       0.73     11.1      6.0
#
# [4 rows x 12 columns]

# %%
from scipy import stats

stats.gmean(dataset.iloc[:], axis = 0)
# Out:
# array([ 8.15169572,  0.49732248,  0.        ,  2.34018918,  0.0816379 ,
#        12.7576619 , 36.62464799,  0.99674489,  3.30752524,  0.64065788,
#        10.37107423,  5.57760205])

# %% [markdown]
# # Frequencies for categorical data

# %%
# the column 'quality' separates the dataset in 6 categories according to the overall quality
dataset.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# # Data visualizations

# %% [markdown]
# ## Distribution of variables

# %% [markdown]
# I chose to use volatile acidity, citric acid, density and ph attributes for the visualizations. The column 'quality' signifies the classes.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dataset['volatile acidity'].hist()

# %%
dataset['citric acid'].hist()

# %%
dataset['density'].hist()

# %%
dataset['pH'].hist()

# %%
select_data = dataset[['volatile acidity', 'citric acid', 'density', 'pH', 'quality']]
select_data
# Out:
#       volatile acidity  citric acid  density    pH  quality
# 0                0.700         0.00  0.99780  3.51        5
# 1                0.880         0.00  0.99680  3.20        5
# 2                0.760         0.04  0.99700  3.26        5
# 3                0.280         0.56  0.99800  3.16        6
# 4                0.700         0.00  0.99780  3.51        5
# ...                ...          ...      ...   ...      ...
# 1594             0.600         0.08  0.99490  3.45        5
# 1595             0.550         0.10  0.99512  3.52        6
# 1596             0.510         0.13  0.99574  3.42        6
# 1597             0.645         0.12  0.99547  3.57        5
# 1598             0.310         0.47  0.99549  3.39        6
#
# [1599 rows x 5 columns]

# %%
axes = select_data.plot.bar(rot = 0, subplots = True, figsize = (15,5))
axes[1].legend(loc=2)

# %% [markdown]
# ## Relationship between certain variables

# %%
# relationship between volatily acidity and citric acid
fig = plt.figure()
select_data.plot.scatter(x= 'volatile acidity', y = 'citric acid', alpha = 0.75,rot=0)
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8]),
#  <a list of 10 Text major ticklabel objects>)

# %%
# relationship between volatily acidity and density
fig = plt.figure()
select_data.plot.scatter(x= 'volatile acidity', y = 'density', alpha = 0.75,rot=0)
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8]),
#  <a list of 10 Text major ticklabel objects>)

# %%
# relationship between volatily acidity and pH
fig = plt.figure()
select_data.plot.scatter(x= 'volatile acidity', y = 'pH', alpha = 0.75,rot=0)
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8]),
#  <a list of 10 Text major ticklabel objects>)

# %%
# relationship between citric acid and density
fig = plt.figure()
select_data.plot.scatter(x= 'citric acid', y = 'density', alpha = 0.75,rot=0)
plt.xticks(rotation=90)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2]),
#  <a list of 8 Text major ticklabel objects>)

# %%
# relationship between citric acid and pH
fig = plt.figure()
select_data.plot.scatter(x= 'citric acid', y = 'pH', alpha = 0.75,rot=0)
plt.xticks(rotation=90)
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2]),
#  <a list of 8 Text major ticklabel objects>)

# %%
# relationship between density and pH
fig = plt.figure()
select_data.plot.scatter(x= 'density', y = 'pH', alpha = 0.75,rot=0)
plt.xticks(rotation=90)
# Out:
# (array([0.988, 0.99 , 0.992, 0.994, 0.996, 0.998, 1.   , 1.002, 1.004,
#         1.006]), <a list of 10 Text major ticklabel objects>)

# %% [markdown]
# ## Column comparison

# %%
select_data['volatile acidity'].hist()
select_data['citric acid'].hist()
select_data['density'].hist()
select_data['pH'].hist()

# %%
boxplot = select_data.boxplot(column=['volatile acidity', 'citric acid', 'density', 'pH'])

# %% [markdown]
# The following visualization shows the quality of wine in relation to the acidity, counted with the pH balance.

# %%
#add your code
import plotly.express as px

ds = dataset.groupby(['volatile acidity','quality'])['pH'].count().reset_index()
ds.columns = ['volatile acidity', 'quality', 'count pH']
ds
# Out:
#      volatile acidity  quality  count pH
# 0               0.120        7         3
# 1               0.160        6         2
# 2               0.180        5         2
# 3               0.180        6         7
# 4               0.180        7         1
# ..                ...      ...       ...
# 339             1.180        5         1
# 340             1.185        3         1
# 341             1.240        5         1
# 342             1.330        5         2
# 343             1.580        3         1
#
# [344 rows x 3 columns]

# %%
fig = px.bar(
    ds, 
    x='quality', 
    y="count pH", 
    color = 'volatile acidity',
    orientation='v', 
    title='the quality of wine per pH balance and acidity', 
    width=800,
    height=500
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="361b9196-4cd7-466c-96c8-c093401cebe1" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("361b9196-4cd7-466c-96c8-c093401cebe1")) {
#                     Plotly.newPlot(
#                         '361b9196-4cd7-466c-96c8-c093401cebe1',
# ...
